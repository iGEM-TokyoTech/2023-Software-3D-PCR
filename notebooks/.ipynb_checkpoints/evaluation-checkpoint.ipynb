# %% [markdown]
# # 必要なライブラリをimprot

# %%
import itertools

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# # 3D-PCRの変数を定義

# %%
sample_size = (12, 8, 10)
lambda_param = 1000

# %% [markdown]
# # 評価に必要な定数の定義

# %%
shot_num = 10000
res = dict(naive=0, arranged=0, equal=0)
log_naive = []
log_arrangement = []
positive_num = []
np.random.seed(0)

# %%
for _ in range(shot_num):
    arr = np.random.exponential(scale=1/lambda_param, size=(12, 8, 10))
    
    rand = np.random.rand(12, 8, 10)
    samples = rand < arr
    
    # positiveの(x, y, z)を取得
    indices = np.nonzero(samples)
    positives = [(indices[0][i], indices[1][i], indices[2][i]) for i in range(len(indices[0]))]

    # positiveになる層のindexを取得
    c_x = np.where(np.any(samples, axis = (1, 2)))[0].tolist()
    c_y = np.where(np.any(samples, axis = (0, 2)))[0].tolist()
    c_z = np.where(np.any(samples, axis = (0, 1)))[0].tolist()
    retest = len(c_x) * len(c_y) * len(c_z)
    
    # better_Arrangement
    sorted_arr = np.flip(np.sort(np.sort(arr.reshape(1, 960)).reshape(10,8,12).T, axis = 0).reshape(12, 8, 10))
    arranged_rand = np.zeros(sample_size)
    
    for i in range(sample_size[0]):
        for j in range(sample_size[1]):
            for k in range(sample_size[2]):
                loc = np.where(sorted_arr == arr[i][j][k])
                x, y, z = loc[0][0], loc[1][0], loc[2][0]
                arranged_rand[x][y][z] = rand[i][j][k]
    
    arranged_samples = arranged_rand < sorted_arr
    indices = np.nonzero(arranged_samples)
    arranged_positives = [(indices[0][i], indices[1][i], indices[2][i]) for i in range(len(indices[0]))]
    
    c_x = np.where(np.any(arranged_samples, axis = (1, 2)))[0].tolist()
    c_y = np.where(np.any(arranged_samples, axis = (0, 2)))[0].tolist()
    c_z = np.where(np.any(arranged_samples, axis = (0, 1)))[0].tolist()
    arranged_retest = len(c_x) * len(c_y) * len(c_z)

    if retest > arranged_retest:
        res['arranged'] += 1
    elif retest < arranged_retest:
        res['naive'] += 1
    else:
        res['equal'] += 1
    log_naive.append(retest)
    log_arrangement.append(arranged_retest)

    positive_num.append(len(positives))
# Out:
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 4]), array([5, 1]), array([3, 6]))
# (array([11]), array([4]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([7]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 3, 10]), array([0, 0]), array([3, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8, 9]), array([5, 1]), array([3, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([0]), array([9]))
# (array([1, 2, 5]), array([5, 1, 0]), array([9, 6, 0]))
# (array([10]), array([1]), array([5]))
# (array([10]), array([1]), array([2]))
# (array([8]), array([2]), array([8]))
# (array([5]), array([3]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([4]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([5]), array([0]))
# (array([11]), array([7]), array([9]))
# (array([8, 8]), array([2, 5]), array([4, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 3]), array([0, 5]), array([4, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([2]), array([7]))
# (array([ 8, 10, 10]), array([2, 3, 7]), array([9, 1, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([2]), array([5]))
# (array([2]), array([2]), array([2]))
# (array([11, 11]), array([1, 5]), array([0, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([6]), array([7]))
# (array([5]), array([4]), array([3]))
# (array([1]), array([2]), array([3]))
# (array([ 0,  3,  8, 10]), array([0, 0, 0, 1]), array([9, 2, 3, 7]))
# (array([4]), array([7]), array([2]))
# (array([4, 4, 6]), array([0, 3, 7]), array([1, 4, 4]))
# (array([6]), array([1]), array([4]))
# (array([ 2, 10]), array([6, 2]), array([0, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([7]), array([2]))
# (array([4]), array([3]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([1]), array([6]))
# (array([ 2, 10]), array([0, 5]), array([4, 0]))
# (array([1]), array([0]), array([3]))
# (array([7]), array([4]), array([8]))
# (array([4]), array([3]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([3]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 2, 5]), array([3, 6, 7]), array([8, 4, 7]))
# (array([ 1, 11]), array([3, 0]), array([7, 0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 8, 8]), array([0, 5, 6]), array([6, 5, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([3]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([1]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5, 6]), array([5, 1]), array([2, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([2]), array([4]))
# (array([7]), array([1]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([1]), array([4]))
# (array([3]), array([3]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([5]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 1, 3, 3, 4, 7, 9]), array([2, 0, 3, 3, 1, 4, 7]), array([2, 0, 2, 4, 9, 4, 5]))
# (array([2]), array([3]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7, 9]), array([5, 3]), array([5, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 7, 9]), array([5, 0, 1]), array([1, 1, 8]))
# (array([2]), array([5]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([7]), array([7]))
# (array([1]), array([5]), array([2]))
# (array([11]), array([2]), array([3]))
# (array([5]), array([4]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 5,  7,  9, 11]), array([4, 6, 2, 7]), array([5, 9, 4, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 2, 6]), array([7, 3, 4]), array([4, 6, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([5]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([6]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 1,  2, 11]), array([5, 5, 0]), array([1, 1, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([0]), array([8]))
# (array([5]), array([7]), array([8]))
# (array([3]), array([7]), array([6]))
# (array([9]), array([2]), array([6]))
# (array([8]), array([6]), array([2]))
# (array([8]), array([6]), array([8]))
# (array([0]), array([7]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([3]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([7]), array([7]))
# (array([8]), array([1]), array([1]))
# (array([3]), array([1]), array([9]))
# (array([8]), array([4]), array([7]))
# (array([3, 4]), array([7, 5]), array([6, 8]))
# (array([3]), array([5]), array([9]))
# (array([10]), array([2]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([7]), array([5]))
# (array([9]), array([2]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([7]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6, 8]), array([3, 3]), array([8, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([1]), array([1]))
# (array([3, 3]), array([6, 6]), array([3, 4]))
# (array([6]), array([4]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([0]), array([8]))
# (array([7]), array([1]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([5]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([3]), array([8]))
# (array([1]), array([4]), array([8]))
# (array([10]), array([7]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([0]), array([0]))
# (array([11]), array([2]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([1]), array([5]))
# (array([2, 6]), array([6, 7]), array([3, 1]))
# (array([6]), array([6]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([0]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([0]), array([2]))
# (array([2]), array([2]), array([8]))
# (array([11]), array([1]), array([9]))
# (array([7]), array([1]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2, 3]), array([2, 6]), array([9, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([3]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([6]), array([9]))
# (array([ 1, 10]), array([2, 2]), array([2, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([3]), array([5]))
# (array([2, 7]), array([1, 4]), array([0, 5]))
# (array([4]), array([4]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([5]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([6]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([7]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 5, 6, 9]), array([2, 4, 0, 0]), array([1, 2, 8, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7, 8]), array([7, 6]), array([1, 1]))
# (array([2, 3]), array([4, 4]), array([0, 1]))
# (array([11]), array([4]), array([8]))
# (array([10, 10, 11]), array([0, 6, 2]), array([9, 6, 1]))
# (array([5]), array([1]), array([8]))
# (array([1, 5]), array([1, 5]), array([7, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 4]), array([7, 2]), array([0, 2]))
# (array([11]), array([6]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([4]), array([2]))
# (array([ 2,  6, 11]), array([4, 1, 6]), array([6, 0, 0]))
# (array([0, 3]), array([0, 7]), array([1, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 6]), array([6, 7]), array([8, 4]))
# (array([1]), array([3]), array([8]))
# (array([4]), array([2]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 2,  3,  4, 10]), array([5, 1, 6, 1]), array([8, 3, 9, 6]))
# (array([11]), array([0]), array([9]))
# (array([11]), array([6]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([2]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([0]), array([7]))
# (array([0, 9]), array([6, 5]), array([2, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([5]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([7]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 5]), array([2, 3]), array([0, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 7, 10, 11]), array([3, 7, 4]), array([6, 0, 0]))
# (array([5, 6]), array([4, 7]), array([9, 3]))
# (array([0, 6]), array([6, 1]), array([5, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 4,  4, 10]), array([4, 5, 5]), array([7, 8, 4]))
# (array([1, 5, 7]), array([1, 2, 7]), array([9, 3, 9]))
# (array([10]), array([6]), array([8]))
# (array([1, 5]), array([7, 6]), array([5, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([3]), array([2]))
# (array([ 8, 10]), array([5, 6]), array([2, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 6,  6,  7,  8, 11]), array([4, 5, 6, 2, 5]), array([0, 6, 5, 8, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([4]), array([0]))
# (array([0]), array([3]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([0]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 7]), array([2, 1]), array([7, 5]))
# (array([0]), array([7]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([3]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([7]), array([2]))
# (array([0, 7]), array([6, 3]), array([2, 6]))
# (array([10]), array([0]), array([3]))
# (array([8]), array([4]), array([1]))
# (array([1, 8]), array([2, 6]), array([0, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 4, 8]), array([0, 0, 3]), array([7, 2, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 2,  3, 10]), array([2, 6, 4]), array([3, 2, 6]))
# (array([2, 4]), array([0, 4]), array([4, 9]))
# (array([11]), array([2]), array([8]))
# (array([0]), array([4]), array([6]))
# (array([4]), array([3]), array([4]))
# (array([9]), array([0]), array([5]))
# (array([5]), array([4]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 5, 7]), array([5, 5, 6]), array([4, 2, 2]))
# (array([3]), array([5]), array([2]))
# (array([0]), array([3]), array([9]))
# (array([10]), array([3]), array([3]))
# (array([1]), array([5]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([2]), array([5]))
# (array([8]), array([1]), array([7]))
# (array([3]), array([7]), array([6]))
# (array([ 7,  7, 10]), array([5, 7, 0]), array([3, 8, 6]))
# (array([ 0,  7, 10]), array([6, 5, 1]), array([6, 5, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6, 9]), array([1, 7]), array([9, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([6]), array([3]))
# (array([6]), array([1]), array([5]))
# (array([8]), array([1]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([5]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([0]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 5]), array([7, 6]), array([2, 5]))
# (array([10]), array([5]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([4]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 5, 10]), array([6, 6]), array([5, 9]))
# (array([7]), array([1]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([2]), array([8]))
# (array([1, 9]), array([4, 6]), array([5, 4]))
# (array([ 0,  3, 11]), array([6, 0, 3]), array([4, 2, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 8]), array([0, 5]), array([6, 9]))
# (array([0]), array([4]), array([2]))
# (array([0]), array([6]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([4]), array([3]))
# (array([ 4,  4,  7, 11]), array([2, 3, 2, 1]), array([9, 4, 2, 4]))
# (array([ 5, 11]), array([7, 2]), array([4, 0]))
# (array([6]), array([4]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([1]), array([6]))
# (array([9]), array([1]), array([3]))
# (array([0, 6]), array([1, 5]), array([9, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([3]), array([5]))
# (array([1]), array([3]), array([3]))
# (array([1, 3]), array([1, 5]), array([2, 8]))
# (array([ 6, 10, 11]), array([7, 6, 7]), array([9, 3, 0]))
# (array([ 1,  8, 10]), array([5, 2, 2]), array([3, 2, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([5]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6, 7]), array([2, 0]), array([6, 5]))
# (array([ 0,  1, 10]), array([7, 5, 2]), array([0, 8, 2]))
# (array([9]), array([0]), array([1]))
# (array([4]), array([6]), array([1]))
# (array([2, 6]), array([2, 5]), array([5, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 8]), array([6, 7]), array([4, 3]))
# (array([7]), array([6]), array([6]))
# (array([8]), array([3]), array([4]))
# (array([ 4,  4, 10]), array([1, 6, 0]), array([6, 6, 7]))
# (array([3]), array([3]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([5]), array([6]))
# (array([2, 8]), array([6, 3]), array([1, 6]))
# (array([4]), array([1]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 2,  9, 11]), array([5, 7, 4]), array([8, 9, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([0]), array([7]))
# (array([1, 4, 6, 9]), array([5, 3, 5, 3]), array([1, 1, 0, 4]))
# (array([3]), array([4]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([7]), array([3]))
# (array([11]), array([7]), array([8]))
# (array([5, 6, 7]), array([5, 7, 4]), array([1, 5, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([6]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([3]), array([5]))
# (array([5]), array([4]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([6]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([3]), array([9]))
# (array([6]), array([5]), array([9]))
# (array([4]), array([0]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([4]), array([7]))
# (array([8]), array([4]), array([0]))
# (array([11]), array([1]), array([7]))
# (array([0, 1]), array([0, 4]), array([4, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([5]), array([3]))
# (array([6, 9]), array([2, 5]), array([2, 2]))
# (array([10]), array([3]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 7, 10]), array([4, 7]), array([1, 3]))
# (array([ 1, 11]), array([4, 0]), array([6, 7]))
# (array([1, 5]), array([6, 7]), array([1, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 7]), array([4, 2]), array([1, 2]))
# (array([1, 7]), array([6, 0]), array([9, 8]))
# (array([ 6,  8, 10]), array([2, 4, 6]), array([0, 1, 7]))
# (array([1]), array([5]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 5]), array([3, 6]), array([5, 3]))
# (array([2, 4]), array([6, 4]), array([0, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([3]), array([5]))
# (array([ 2, 10]), array([2, 1]), array([5, 3]))
# (array([0, 7]), array([6, 7]), array([5, 3]))
# (array([8]), array([5]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6, 6]), array([3, 7]), array([9, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([2]), array([1]))
# (array([ 0,  2, 10]), array([5, 0, 1]), array([3, 5, 0]))
# (array([ 1, 11]), array([5, 1]), array([9, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([2]), array([5]))
# (array([4]), array([1]), array([5]))
# (array([3]), array([2]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([0]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([6]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([5]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([0]), array([4]))
# (array([1, 1, 2]), array([3, 6, 0]), array([8, 5, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([6]), array([2]))
# (array([ 9, 10]), array([6, 6]), array([4, 0]))
# (array([2]), array([0]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 4, 6]), array([2, 7, 3]), array([2, 3, 4]))
# (array([3]), array([2]), array([2]))
# (array([8, 8]), array([0, 0]), array([0, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([0]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6, 8]), array([5, 7]), array([7, 1]))
# (array([5]), array([7]), array([1]))
# (array([6]), array([6]), array([1]))
# (array([3]), array([5]), array([1]))
# (array([1]), array([7]), array([8]))
# (array([2]), array([6]), array([5]))
# (array([2, 8]), array([5, 4]), array([5, 5]))
# (array([10]), array([3]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([3]), array([2]))
# (array([4, 9]), array([1, 3]), array([4, 5]))
# (array([3]), array([7]), array([5]))
# (array([5]), array([0]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 4]), array([2, 5]), array([0, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([5]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([0]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 6, 10]), array([7, 1]), array([1, 2]))
# (array([4]), array([6]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([1]), array([7]))
# (array([1]), array([1]), array([0]))
# (array([ 2,  2, 11]), array([0, 4, 4]), array([6, 7, 9]))
# (array([7, 9]), array([2, 5]), array([4, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 6]), array([3, 0]), array([5, 9]))
# (array([7]), array([1]), array([4]))
# (array([6]), array([3]), array([2]))
# (array([6]), array([6]), array([9]))
# (array([ 0, 10, 11]), array([0, 2, 3]), array([7, 7, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 4]), array([0, 2]), array([6, 0]))
# (array([9]), array([0]), array([7]))
# (array([9]), array([5]), array([5]))
# (array([9]), array([1]), array([8]))
# (array([6]), array([3]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 5]), array([2, 0]), array([0, 2]))
# (array([0]), array([6]), array([7]))
# (array([9]), array([2]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([7]), array([3]))
# (array([ 4, 11]), array([1, 0]), array([1, 3]))
# (array([11]), array([2]), array([9]))
# (array([8]), array([0]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 3]), array([4, 4]), array([7, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([3]), array([6]))
# (array([ 0,  5, 10]), array([2, 4, 1]), array([1, 5, 5]))
# (array([0, 6]), array([2, 6]), array([2, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 2, 11]), array([0, 1]), array([9, 6]))
# (array([5, 6, 6]), array([3, 1, 2]), array([4, 2, 5]))
# (array([ 9, 11]), array([3, 2]), array([0, 2]))
# (array([7]), array([0]), array([8]))
# (array([1]), array([7]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2, 3, 8]), array([2, 7, 5]), array([0, 7, 2]))
# (array([3]), array([0]), array([5]))
# (array([8]), array([5]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([1]), array([5]))
# (array([4]), array([0]), array([0]))
# (array([6]), array([3]), array([3]))
# (array([2, 9]), array([6, 3]), array([3, 6]))
# (array([10]), array([2]), array([7]))
# (array([1]), array([0]), array([0]))
# (array([7]), array([0]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([4]), array([6]))
# (array([5]), array([7]), array([1]))
# (array([9]), array([5]), array([8]))
# (array([ 5, 10]), array([0, 5]), array([9, 0]))
# (array([7]), array([5]), array([8]))
# (array([0]), array([1]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([3]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([5]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([1]), array([6]))
# (array([ 7, 10]), array([5, 1]), array([9, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 3]), array([1, 2]), array([9, 4]))
# (array([3]), array([3]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([2]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([5]), array([8]))
# (array([1, 6]), array([1, 0]), array([5, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2, 3]), array([7, 5]), array([1, 7]))
# (array([11, 11]), array([5, 7]), array([9, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 1,  3, 11]), array([2, 7, 0]), array([6, 1, 8]))
# (array([ 3, 11]), array([2, 4]), array([9, 1]))
# (array([4]), array([0]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 5, 8]), array([4, 2, 4]), array([7, 4, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 0, 10]), array([7, 4]), array([7, 0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([4]), array([9]))
# (array([ 7, 11]), array([7, 2]), array([7, 1]))
# (array([0, 7]), array([5, 7]), array([9, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2, 5, 9]), array([4, 7, 5]), array([3, 2, 0]))
# (array([9]), array([6]), array([5]))
# (array([ 5, 11]), array([7, 3]), array([2, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([1]), array([6]))
# (array([0]), array([0]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5, 5, 6, 8]), array([3, 4, 0, 7]), array([0, 2, 6, 6]))
# (array([10, 10, 10]), array([1, 1, 6]), array([3, 6, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([4]), array([3]))
# (array([9]), array([6]), array([5]))
# (array([0, 3, 4]), array([7, 4, 6]), array([5, 2, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5, 8]), array([7, 5]), array([3, 9]))
# (array([5]), array([3]), array([9]))
# (array([11]), array([5]), array([8]))
# (array([6]), array([0]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([4]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([2]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 1, 10]), array([2, 7]), array([2, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7, 9]), array([6, 4]), array([8, 5]))
# (array([10]), array([2]), array([6]))
# (array([11]), array([0]), array([3]))
# (array([10]), array([5]), array([4]))
# (array([0, 3, 4, 5]), array([0, 5, 1, 3]), array([3, 7, 6, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([5]), array([8]))
# (array([2]), array([4]), array([9]))
# (array([3, 4]), array([7, 4]), array([0, 2]))
# (array([7]), array([4]), array([3]))
# (array([6]), array([7]), array([6]))
# (array([4]), array([5]), array([8]))
# (array([8, 8]), array([1, 5]), array([5, 0]))
# (array([4, 8]), array([7, 4]), array([4, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([1]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 4, 7]), array([2, 3, 7]), array([2, 6, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([0]), array([7]))
# (array([9]), array([3]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 2, 10]), array([1, 7]), array([4, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([0]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([1]), array([8]))
# (array([11]), array([5]), array([2]))
# (array([0]), array([0]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([3]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([0]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([3]), array([4]))
# (array([ 8, 11]), array([5, 4]), array([9, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([7]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 2]), array([4, 2]), array([6, 9]))
# (array([4]), array([6]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([5]), array([6]))
# (array([2, 4, 7]), array([7, 1, 3]), array([0, 2, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([1]), array([7]))
# (array([6]), array([4]), array([7]))
# (array([3]), array([4]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([6]), array([4]))
# (array([0, 3]), array([5, 2]), array([7, 1]))
# (array([1]), array([2]), array([4]))
# (array([1]), array([1]), array([9]))
# (array([2, 8]), array([1, 4]), array([8, 8]))
# (array([10]), array([7]), array([9]))
# (array([0]), array([4]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 7, 8]), array([7, 0, 4]), array([0, 8, 5]))
# (array([10]), array([7]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([0]), array([7]))
# (array([9]), array([2]), array([3]))
# (array([2]), array([1]), array([1]))
# (array([4, 6]), array([5, 1]), array([8, 4]))
# (array([10]), array([4]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([7]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([3]), array([1]))
# (array([ 7, 11]), array([6, 0]), array([5, 1]))
# (array([5, 8]), array([1, 3]), array([4, 0]))
# (array([5]), array([3]), array([2]))
# (array([0, 3]), array([3, 0]), array([7, 7]))
# (array([6]), array([2]), array([1]))
# (array([1, 2, 9]), array([7, 0, 4]), array([4, 8, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 0, 11]), array([2, 5]), array([6, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([0]), array([6]))
# (array([0]), array([5]), array([6]))
# (array([1, 4]), array([5, 7]), array([1, 4]))
# (array([11]), array([1]), array([7]))
# (array([6]), array([2]), array([5]))
# (array([4]), array([2]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([3]), array([0]))
# (array([0, 9]), array([5, 2]), array([1, 1]))
# (array([ 3, 11]), array([1, 1]), array([7, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([6]), array([0]))
# (array([3]), array([7]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([5]), array([3]))
# (array([11]), array([7]), array([4]))
# (array([1]), array([7]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 4]), array([0, 5]), array([5, 8]))
# (array([11]), array([2]), array([1]))
# (array([3]), array([4]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([6]), array([1]))
# (array([8]), array([4]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([4]), array([1]))
# (array([4]), array([1]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([5]), array([5]))
# (array([1, 1, 2]), array([4, 7, 0]), array([4, 6, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([7]), array([2]))
# (array([8]), array([4]), array([8]))
# (array([8, 8]), array([1, 3]), array([2, 0]))
# (array([6]), array([3]), array([2]))
# (array([10]), array([0]), array([4]))
# (array([3]), array([7]), array([1]))
# (array([1]), array([6]), array([4]))
# (array([0, 4, 8]), array([4, 6, 2]), array([6, 7, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([1]), array([2]))
# (array([8]), array([5]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([7]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 3]), array([1, 0]), array([8, 1]))
# (array([11]), array([6]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([3]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([0]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8, 8]), array([4, 5]), array([4, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 1]), array([5, 7]), array([6, 5]))
# (array([9]), array([4]), array([9]))
# (array([7]), array([4]), array([8]))
# (array([10]), array([4]), array([6]))
# (array([6]), array([2]), array([5]))
# (array([6]), array([1]), array([5]))
# (array([8]), array([4]), array([7]))
# (array([10]), array([5]), array([2]))
# (array([3, 5]), array([0, 5]), array([3, 6]))
# (array([4]), array([7]), array([2]))
# (array([0]), array([5]), array([4]))
# (array([ 0,  6, 10]), array([4, 5, 2]), array([5, 8, 1]))
# (array([ 3, 11]), array([5, 2]), array([6, 1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([5]), array([4]))
# (array([2, 3]), array([7, 1]), array([3, 0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 9]), array([4, 2]), array([5, 5]))
# (array([4]), array([7]), array([4]))
# (array([4]), array([3]), array([0]))
# (array([10, 11]), array([5, 3]), array([5, 6]))
# (array([11]), array([6]), array([2]))
# (array([8, 9]), array([2, 1]), array([7, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([3]), array([2]))
# (array([5, 9]), array([2, 4]), array([1, 7]))
# (array([1]), array([6]), array([0]))
# (array([3]), array([3]), array([3]))
# (array([11]), array([1]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([0]), array([5]))
# (array([0, 2]), array([4, 6]), array([9, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([5]), array([0]))
# (array([2]), array([3]), array([4]))
# (array([ 0, 11]), array([0, 0]), array([7, 9]))
# (array([ 3,  9, 10]), array([0, 7, 7]), array([4, 7, 4]))
# (array([2]), array([5]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([3]), array([9]))
# (array([ 2, 11]), array([1, 1]), array([9, 0]))
# (array([1]), array([7]), array([7]))
# (array([1]), array([6]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([7]), array([0]))
# (array([8]), array([6]), array([2]))
# (array([5, 5, 9]), array([3, 5, 3]), array([5, 0, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([2]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([6]), array([9]))
# (array([2]), array([7]), array([7]))
# (array([11]), array([3]), array([7]))
# (array([0]), array([0]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 1, 6, 8]), array([0, 0, 2, 4]), array([2, 4, 2, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 5, 10]), array([3, 4]), array([3, 9]))
# (array([11]), array([3]), array([1]))
# (array([2]), array([6]), array([6]))
# (array([11]), array([3]), array([0]))
# (array([3]), array([3]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([7]), array([1]))
# (array([4]), array([5]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([6]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([6]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([3]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([1]), array([4]))
# (array([6, 8]), array([1, 1]), array([7, 3]))
# (array([0]), array([2]), array([3]))
# (array([4]), array([1]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([6]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([6]), array([9]))
# (array([0, 4]), array([0, 2]), array([6, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 6, 7]), array([1, 0, 7]), array([1, 0, 8]))
# (array([0, 8]), array([4, 4]), array([9, 2]))
# ...
# (array([3, 4]), array([0, 1]), array([0, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([5]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2, 4]), array([5, 2]), array([1, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([5]), array([2]))
# (array([5]), array([2]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 8]), array([4, 2]), array([3, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3, 8]), array([7, 1]), array([9, 2]))
# (array([1]), array([2]), array([9]))
# (array([1, 5]), array([5, 1]), array([0, 0]))
# (array([1]), array([7]), array([2]))
# (array([6]), array([5]), array([6]))
# (array([3]), array([7]), array([9]))
# (array([4]), array([1]), array([3]))
# (array([ 2,  6, 11]), array([3, 2, 3]), array([9, 0, 8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([4]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([5]), array([4]))
# (array([11]), array([1]), array([5]))
# (array([3]), array([2]), array([8]))
# (array([10, 11]), array([6, 7]), array([8, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([1]), array([7]))
# (array([2, 9]), array([7, 5]), array([9, 1]))
# (array([6]), array([7]), array([0]))
# (array([6]), array([5]), array([4]))
# (array([0]), array([2]), array([0]))
# (array([3]), array([1]), array([0]))
# (array([5]), array([5]), array([1]))
# (array([1, 2, 9]), array([3, 4, 1]), array([9, 1, 1]))
# (array([6, 6]), array([1, 6]), array([5, 9]))
# (array([4, 6]), array([5, 6]), array([1, 5]))
# (array([10]), array([2]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([6]), array([0]))
# (array([0, 4]), array([3, 2]), array([5, 5]))
# (array([10]), array([6]), array([6]))
# (array([3, 5]), array([6, 6]), array([7, 5]))
# (array([8]), array([3]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 5]), array([2, 6]), array([1, 4]))
# (array([8]), array([5]), array([1]))
# (array([9]), array([3]), array([8]))
# (array([0, 1, 8]), array([1, 3, 0]), array([4, 8, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 7]), array([6, 1]), array([8, 2]))
# (array([4, 6]), array([5, 1]), array([7, 4]))
# (array([0, 1, 3]), array([2, 1, 2]), array([8, 3, 7]))
# (array([6]), array([2]), array([5]))
# (array([7]), array([3]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 0]), array([3, 7]), array([8, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 3, 10, 10]), array([6, 3, 3]), array([8, 1, 5]))
# (array([8]), array([3]), array([3]))
# (array([4]), array([0]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([6]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5, 9]), array([7, 3]), array([9, 2]))
# (array([3]), array([2]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([0]), array([2]))
# (array([10]), array([4]), array([3]))
# (array([7]), array([0]), array([4]))
# (array([8]), array([0]), array([8]))
# (array([3, 4, 4]), array([0, 0, 1]), array([2, 0, 2]))
# (array([1, 3]), array([5, 5]), array([3, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([4]), array([8]))
# (array([9]), array([6]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([5]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0]), array([5]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([3]), array([8]))
# (array([1]), array([1]), array([5]))
# (array([1]), array([0]), array([4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([7]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([3]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 5, 6, 9]), array([0, 0, 5, 7]), array([3, 9, 9, 6]))
# (array([ 2, 11]), array([5, 2]), array([5, 0]))
# (array([5]), array([1]), array([0]))
# (array([1]), array([5]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2]), array([0]), array([5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 1, 7]), array([0, 5, 7]), array([5, 8, 6]))
# (array([2]), array([7]), array([9]))
# (array([4, 6]), array([7, 3]), array([0, 5]))
# (array([10]), array([0]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8, 8]), array([6, 6]), array([1, 5]))
# (array([10]), array([5]), array([2]))
# (array([11]), array([4]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 4,  7, 10]), array([5, 0, 6]), array([0, 7, 2]))
# (array([4]), array([7]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([7]), array([2]))
# (array([9]), array([7]), array([9]))
# (array([9]), array([4]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([3]), array([8]))
# (array([5]), array([1]), array([6]))
# (array([11]), array([2]), array([7]))
# (array([1, 2]), array([4, 2]), array([8, 7]))
# (array([ 7, 11]), array([3, 7]), array([1, 7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([1]), array([9]))
# (array([5, 9]), array([1, 1]), array([7, 6]))
# (array([ 8, 10]), array([2, 3]), array([5, 2]))
# (array([6]), array([4]), array([4]))
# (array([0, 1]), array([2, 3]), array([6, 9]))
# (array([10]), array([6]), array([2]))
# (array([3]), array([1]), array([1]))
# (array([10]), array([2]), array([9]))
# (array([ 3,  9, 11]), array([2, 2, 2]), array([9, 2, 9]))
# (array([8]), array([0]), array([6]))
# (array([9]), array([1]), array([4]))
# (array([0]), array([5]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([5]), array([7]))
# (array([1]), array([3]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 4]), array([0, 0]), array([6, 7]))
# (array([4]), array([3]), array([0]))
# (array([ 1,  5, 10]), array([7, 5, 5]), array([0, 3, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([4]), array([6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8, 9]), array([5, 7]), array([8, 9]))
# (array([8]), array([2]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([5]), array([2]))
# (array([4]), array([7]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([8]), array([0]), array([7]))
# (array([0]), array([0]), array([1]))
# (array([0]), array([3]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([0]), array([9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 7]), array([4, 5]), array([6, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([0]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([1]), array([1]))
# (array([ 5,  8, 10]), array([2, 2, 2]), array([0, 8, 6]))
# (array([7]), array([7]), array([7]))
# (array([1]), array([1]), array([6]))
# (array([5]), array([0]), array([8]))
# (array([8]), array([2]), array([1]))
# (array([4, 8]), array([3, 2]), array([2, 6]))
# (array([1, 8]), array([7, 0]), array([9, 8]))
# (array([ 0, 11]), array([1, 0]), array([0, 2]))
# (array([4]), array([4]), array([0]))
# (array([0, 2]), array([6, 5]), array([8, 7]))
# (array([1, 9]), array([6, 7]), array([5, 5]))
# (array([3]), array([7]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 3,  6, 10]), array([4, 7, 5]), array([8, 2, 7]))
# (array([ 7, 10, 11]), array([7, 6, 5]), array([0, 8, 6]))
# (array([2]), array([0]), array([9]))
# (array([1]), array([3]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([5]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([5]), array([7]))
# (array([0, 2]), array([3, 6]), array([0, 2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([9]), array([4]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4, 4, 4]), array([1, 2, 6]), array([4, 4, 9]))
# (array([4]), array([5]), array([2]))
# (array([7]), array([0]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([0]), array([5]))
# (array([8]), array([4]), array([4]))
# (array([3, 4]), array([2, 5]), array([9, 3]))
# (array([3, 3, 4, 5, 5]), array([4, 5, 5, 0, 1]), array([2, 2, 7, 1, 7]))
# (array([1]), array([0]), array([9]))
# (array([7, 9]), array([5, 0]), array([1, 9]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([6]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([0]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([3]), array([3]), array([6]))
# (array([5]), array([7]), array([8]))
# (array([1, 2, 5]), array([3, 2, 4]), array([1, 3, 0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([7]), array([5]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([1]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([3]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([1]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([6]), array([9]))
# (array([7]), array([2]), array([7]))
# (array([2, 3]), array([2, 2]), array([2, 4]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 8]), array([1, 1]), array([5, 5]))
# (array([ 4, 11]), array([0, 3]), array([7, 5]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 3, 7]), array([5, 4, 2]), array([9, 1, 3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([0, 7, 8]), array([2, 7, 4]), array([3, 5, 9]))
# (array([ 4,  7, 11]), array([3, 3, 2]), array([9, 9, 7]))
# (array([ 4,  4,  9, 10]), array([4, 7, 2, 6]), array([9, 2, 4, 3]))
# (array([11]), array([3]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([2, 8]), array([1, 4]), array([3, 7]))
# (array([10]), array([7]), array([0]))
# (array([10]), array([0]), array([8]))
# (array([7]), array([7]), array([2]))
# (array([10]), array([6]), array([6]))
# (array([3]), array([0]), array([1]))
# (array([10]), array([1]), array([8]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([ 3, 11]), array([4, 6]), array([7, 6]))
# (array([0]), array([4]), array([7]))
# (array([4]), array([1]), array([6]))
# (array([4]), array([0]), array([5]))
# (array([8]), array([0]), array([3]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([10]), array([4]), array([7]))
# (array([ 8, 10, 11]), array([0, 4, 3]), array([3, 1, 6]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([11]), array([2]), array([7]))
# (array([8]), array([6]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1]), array([5]), array([2]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([1, 5]), array([4, 2]), array([3, 3]))
# (array([0]), array([3]), array([1]))
# (array([0]), array([1]), array([5]))
# (array([2, 5]), array([6, 0]), array([0, 3]))
# (array([ 0, 11]), array([1, 6]), array([8, 8]))
# (array([1]), array([7]), array([4]))
# (array([4]), array([1]), array([7]))
# (array([3]), array([7]), array([8]))
# (array([7]), array([3]), array([8]))
# (array([3, 4]), array([7, 3]), array([2, 8]))
# (array([ 3,  4,  9, 11]), array([7, 6, 1, 0]), array([3, 0, 7, 2]))
# (array([11]), array([4]), array([0]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([4]), array([6]), array([4]))
# (array([5, 6, 8]), array([3, 1, 4]), array([8, 3, 2]))
# (array([2, 5]), array([3, 3]), array([6, 0]))
# (array([9]), array([4]), array([7]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([6]), array([6]), array([4]))
# (array([1]), array([5]), array([1]))
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))
# (array([5]), array([3]), array([8]))

# %%
fig, ax = plt.subplots()
ax.bar(['naive', 'arrangement', 'euqal'], list(res.values()))
ax.set_title(f'Number of times that fewer inspections could be performed by \
\n comparing naive and arrangement(lambda={lambda_param}, {shot_num}shots, {sum(positive_num)/shot_num} positives(ave))')
# Out:
# Text(0.5, 1.0, 'Number of times that fewer inspections could be performed by \n comparing naive and arrangement(lambda=1000, 10000shots, 0.9557 positives(ave))')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar(['naive', 'arrangement'], [sum(log_naive), sum(log_arrangement)])
# ax.bar(['naive', 'arrangement'], [0, sum(log_naive) - sum(log_arrangement)], bottom=[sum(log_naive), sum(log_arrangement)])
ax.set_title(f'Number of retest samples ({sum(log_naive) - sum(log_arrangement)}) without and with arrangement \
\n (lambda={lambda_param}, {shot_num}shots, {sum(positive_num)/shot_num} positives(ave))')
# Out:
# Text(0.5, 1.0, 'Number of retest samples (13236) without and with arrangement \n (lambda=500, 10000shots, 1.8994 positives(ave))')
